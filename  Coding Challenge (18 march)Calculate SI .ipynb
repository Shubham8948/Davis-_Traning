# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubham8948/Davis-_Traning/blob/main/%20Coding%20Challenge%20(18%20march)Calculate%20SI%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# create a function to calculate simple intrest

def simple_interest(p=0, r=0, t=0):
    si = (p * r * t) / 100
    return si

P = float(input("Enter P: "))
R = float(input("Enter R: "))
T = float(input("Enter T: "))

print("Simple Interest =", simple_interest(P, R, T))
# Out:
# Enter P: 22
# Enter R: 45
# Enter T: 60
# Simple Interest = 594.0
