# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubham8948/Davis-_Traning/blob/main/%20Q2.%20Python%20lab%20work%20Assignment%3A%20List%2C%20Tuple%2C%20Set%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#list rotation to the right by k position
lst = [10, 20, 30, 40, 50]
k = 2

k = k % len(lst)

rotated = lst[-k:] + lst[:-k]

print(rotated)
# Out:
# [40, 50, 10, 20, 30]
