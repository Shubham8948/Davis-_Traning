# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubham8948/Davis-_Traning/blob/main/%20Coding%20Challenge%20(18%20march)discount%204%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
price = float(input("Enter price: "))
discount = float(input("Enter discount percentage: "))

if discount > 0:
    final_price = price - (price * discount / 100)
else:
    final_price = price

print("Final price after discount =", final_price)
# Out:
# Enter price: 250
# Enter discount percentage: 18
# Final price after discount = 205.0
