# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubham8948/Davis-_Traning/blob/main/%20Coding%20Challenge%20(18%20march)even%20number%201%20to%20N.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# to print all even numbers between 1 to N

N = int(input("Enter N: "))

for i in range(1, N + 1):
    if i % 2 == 0:
        print(i, end=" ")
# Out:
# Enter N: 9
# 2 4 6 8
