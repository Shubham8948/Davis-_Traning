# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubham8948/Davis-_Traning/blob/main/%20Q12.%20Python%20lab%20work%20Assignment%3A%20List%2C%20Tuple%2C%20Set%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#common element in three lists
a = [1, 2, 3]
b = [2, 3, 4]
c = [2, 5, 3]

result = list(set(a) & set(b) & set(c))

print(result)
# Out:
# [2, 3]
