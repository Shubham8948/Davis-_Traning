# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubham8948/Davis-_Traning/blob/main/Python%20lab%20work%20Assignment%3A%20List%2C%20Tuple%2C%20Set%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#find all duplicate element in given list
numbers = [1, 2, 3, 2, 4, 5, 1]

dup = []

for i in numbers:
    if numbers.count(i) > 1 and i not in dup:
        dup.append(i)

print(dup)
# Out:
# [1, 2]
