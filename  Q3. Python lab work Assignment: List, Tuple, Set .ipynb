# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubham8948/Davis-_Traning/blob/main/%20Q3.%20Python%20lab%20work%20Assignment%3A%20List%2C%20Tuple%2C%20Set%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#remove common element from two lists
list1 = [1, 2, 3, 4]
list2 = [3, 4, 5]

result = []

for i in list1:
    if i not in list2:
        result.append(i)

print(result)
# Out:
# [1, 2]
