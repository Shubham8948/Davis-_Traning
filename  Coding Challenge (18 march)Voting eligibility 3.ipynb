# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubham8948/Davis-_Traning/blob/main/%20Coding%20Challenge%20(18%20march)Voting%20eligibility%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#  to check a person is eligible to vote
age = int(input("Enter age: "))

result = "Eligible" if age >= 18 else "Not Eligible"

print(result)
# Out:
# Enter age: 55
# Eligible
