# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubham8948/Davis-_Traning/blob/main/%20Q5.%20Python%20lab%20work%20Assignment%3A%20List%2C%20Tuple%2C%20Set%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# convert list od tuple and remove duplicates
lst = [1, 2, 2, 3, 4, 4]

t = tuple(set(lst))

print(t)
# Out:
# (1, 2, 3, 4)
