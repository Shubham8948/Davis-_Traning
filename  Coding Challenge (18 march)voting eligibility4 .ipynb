# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubham8948/Davis-_Traning/blob/main/%20Coding%20Challenge%20(18%20march)voting%20eligibility4%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def vote(age):
    if age >= 18:
        print("Eligible")
    if age < 18:
        print("Not Eligible")

age = int(input("Enter age: "))

vote(age)
# Out:
# Enter age: 16
# Not Eligible
