# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubham8948/Davis-_Traning/blob/main/%20Coding%20Challenge%20(18%20march)voting%20eligibility3%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
while True:
    age = int(input("Enter age: "))

    if age >= 18:
        print("Eligible")
    else:
        print("Not Eligible")

    break
# Out:
# Enter age: 23
# Eligible
